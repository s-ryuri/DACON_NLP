# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn import (datasets, feature_extraction, linear_model, metrics)
from sklearn import neural_network
import re
import pandas as pd
from konlpy.tag import Okt
from sklearn.model_selection import train_test_split
from soylemma import Lemmatizer

from sklearn import svm
from sklearn import (tree, ensemble)
from sklearn.neural_network import MLPClassifier

# %%
def read_data():
    train = pd.read_csv('./data/train_data.csv')
#     cate = pd.read_csv('./data/topic_dict.csv')
    X = np.array([x for x in train['title']])
    y = np.array([x for x in train['topic_idx']])
    X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=.2,random_state=0)
    
    
    return X_train, X_test, y_train, y_test

# %%
X_train, X_test, y_train, y_test = read_data()

# %%
df_train = pd.DataFrame(X_train, columns=['title'])
df_train
# Out:
#                                       title
# 0         신한금융 박병대 등 사외이사 선임…주당 1천450원 배당종합
# 1              SKT 새학기 맞아 초·중·고·대학생 맞춤혜택 제공
# 2          프로배구 상승세 주역 다우디·이다영 3라운드 남녀부 MVP
# 3          월드컵 문대통령 멕시코전 때 붉은색 유니폼 입고 선수...
# 4                KT 기업용 유·무선 네트워크 보안 서비스 출시
# ...                                     ...
# 36518        데얀 멀티골 수원 AFC 챔스리그 시드니 원정 승리종합
# 36519             포털 중심 뉴스 개선 위해 아웃링크 법제화해야
# 36520               갈루치 북미접촉 결과 차기 美행정부에 전달
# 36521        이승만 국부론 여진…한상진 해명·김종인 정면비판종합2보
# 36522  MWC 주인공 될 새 폰은…LG 듀얼 디스플레이폰 공개 가능성종합
#
# [36523 rows x 1 columns]

# %%
def preprocessing(X_train, stopwords):
    X_train['title'] = X_train['title'].str.replace("[^a-zA-Z가-힣 ]"," ")
    
    tokenizer = Okt()
    res = []
    for sentence in X_train['title']:
        tmp = []
        tmp = tokenizer.morphs(sentence)

        tokenized = []
        for token in tmp:
            if token not in stopwords and len(token) >= 2:
                tokenized.append(token)
        res.append(' '.join(tokenized))
        
    return res

# %%
def train(X_train, target, model):
    clf  = model
    clf.fit(X_train, target)

    return clf

# %%
def test(model, X_test, y_test):
    return model.score(X_test, y_test)

# %%
def vectorizor(dataset, dataset1):
    vectorizer = feature_extraction.text.TfidfVectorizer(sublinear_tf=True, smooth_idf=True, ngram_range=(1, 2))
    vectorizer.fit(dataset)
    x_data = vectorizer.transform(dataset)
    x_test = vectorizer.transform(dataset1)
    return x_data, x_test, vectorizer

# %%
res = preprocessing(df_train, stopword)

# %%
res
# Out:
# ['금융 박병대 사외이사 선임 주당 배당 종합',
#  'SKT 학기 맞아 대학생 맞춤 혜택 제공',
#  '프로배구 상승세 주역 다우 라운드 남녀 MVP',
#  '월드컵 대통령 멕시코 은색 유니폼 입고 선수',
#  'KT 기업 무선 네트워크 보안 서비스 출시',
#  'KEB 하나은행 광주 외국인 근로자 일요 영업 개점',
#  '오면 공기 맑아진다고 장마철 에도 미세먼지 나쁨',
#  '웰컴 저축은행 정기예금 금리 인상 개월 맡겨도',
#  '이란 대통령 걸프 국가 호르무즈 평화 계획 친서 보내',
#  '기자 협회 국제 교류 재단 인도네시아 자단 초청',
#  '에스티 억원 전환사채 발행 결정',
#  '거래소 한국 맥널티 주가 급등 조회 공시 요구',
#  '토종 득점 선민 연말 시상식 오겠다는 목표',
#  '한중일 통신 기술 책임자 IoT 국제 표준화 논의',
#  '프로 구단 단장 선수 출신 비율 야구',
#  '경찰서 찾아가 모친 흉기 살해 하려 아들 기소 종합',
#  '이통 불법행위 신속 배상 조사 심의 중간 종결',
#  '다케시마 행사 중앙정부 차관 참석',
#  '네이마르 PK 바르사 국왕컵 차전 승리',
#  'KBS 교향악단 여수 클래식 음악 축제 개최',
#  '올림픽 북한 응원단 물방울 맞아도 싱글벙글',
#  '드론 위기 완화 역할',
#  '삼성 생명 토마스 여자 프로농구 라운드 MVP 통산 번째',
#  '장병철 감독 삼성 화재 경기 보고 고참 중요성 느껴',
#  '영남 참가 자제 코로나 우는 대구 경북',
#  '게시판 NH 투자 증권 시대 아카데미',
#  '프로농구 올스타전 걸그룹 EXID 축하공연',
#  '홍용표 김정은 국제사회 조롱 행태 단호 대응 필요',
#  '지난해 증권사 순이익 조원 만에 최대',
#  '중간 신영석 주장 위아래 똘똘 뭉친 남자배구 대표팀',
#  '회고록 논란 열까 NLL 대화 록땐 사흘 만에 반응',
#  '확대 간부 회의 참석자 인사 하는 이해찬',
#  '인스타그램 쇼핑 한다 사진 태그 누르면 연결 종합',
#  '국방 군사 회담 제의 지체 없이 화답 촉구',
#  'AFC 챔스리그 탈락 수원 지상 과제 울산 극복',
#  '아자르 멀티골 선두 첼시 맨시티 승리',
#  '스웨덴 정부 미국 요청 부패 사범 다시 체포',
#  'VR AR 사회 여파 민간 평가 활동 시작',
#  '민주 긴급 대위 소집 국민의당 긴급 최고',
#  '홍콩 시위 갈등 격화 엄중 교섭 제기 vs 대사 초치',
#  '마이너 리그 문찬종 친구 격려 받고 왔죠',
#  '잠긴 인삼 태양광 발전 시설',
#  '책무 수행 어려워질 아키히토 일왕 생전 퇴위 의향 발표 종합',
#  '그래픽 네이버 로봇 개발 본격 자율 주행 로봇 공개',
#  '휴대전화 TV 전자파 막는 신소재 개발',
#  '대통령 ASEM 정상 회의 참석 몽골 방문 출국 종합',
#  '갤럭시 기다렸어요 개통 고객 탄생',
#  '외국인투자 정책 협의',
#  '쌍용차 임금 소송 승소 순이익 증가',
#  '호주 한인 극단 한영 이중 언어 뮤지컬 현지 관객 극찬',
#  '지능 정보사회 기술 혁신 이끌 원천 기술 개발 착수',
#  '카카오 신년 인사 폭주 불통',
#  '중국 심야 가던 여성 묻지 폭행 논란',
#  '이리 닮았다는 여수 낭도 사람 마음씨 같은',
#  '게시판 금융 위원장 국제사회 금융 협력 기구 의장 접견',
#  '소설 년생 김지영 개월 만에 판매',
#  '과학 ICT 정책 공유 정통부 과학기술 토론회 개최',
#  'NC 만의 연승 베렛 만의 승리투수',
#  '아가 상태 신영철 아냐 최태웅',
#  '카드 수수료 대로 인하 추진 정부 예산 넣고 회비 인상',
#  '고양시 향동 지구 다방 기승 단속 해도 효과 없어',
#  '올림픽 태권도 시범 리허설 갑니다',
#  '아프리카 투자 확대 나선 경계 약속 보다는 성과 중요',
#  '네이버 공공 금융 클라우드 집중 공략 AWS MS 본격 경쟁 종합',
#  'NBA 미네소타 LA 레이커스 역전승 승차',
#  '한국 거래소 싱가포르 홍콩 코스닥 IR 개최',
#  '대회 중앙 TV 오후 시보 도서 대회 언급 안해',
#  '온라인 커뮤니티 뽐뿌 랜섬 웨어 피해 속출',
#  'LGU 하반기 빌딩 구축 시작 강변 테크노마트 실증 완료',
#  '박지수 트리플 더블 여자농구 KB 개막 연승 질주',
#  '하피 스트 곽정 이스라엘 국제 하프 콩쿠르 심사 위원 위촉',
#  '김정은 청와대 타격 방법 확인 목적 전투 훈련 참관 종합',
#  '여자농구 신한은행 KDB 생명 대승 연승 휘파람',
#  '미스터 샤인 프로 부족 인물 납작해',
#  '청문 보고서 채택 없이 임명 장관 원칙 위배 없다',
#  '이통 주파수 경매 참여 신청 원대 전쟁 종합',
#  '신간 집은 아니지만 사는 입니다',
#  'KT 상용 마지막 콘서트 중계',
#  '한국 항공우주 분기 영업 이익 억원 증가',
#  '아시안 게임 개회 기수 임영희 여자농구 단일 분위',
#  '영상 검찰 개혁 대규모 촛불집회 검찰 헌법 국민 군림',
#  '흥국생명 위로 도약 김희진 IBK 기업은행 연패',
#  '대포 득점 SK 삼성 상대로 이틀 연속 홈런 파티',
#  '집단 대출 상호금융 주택 담보 대출 심사 강화 분할 상환',
#  '신한카드 아파트 관리 조회 서비스',
#  '특징 삼성 바이오 감리 심의 받은 종합',
#  'KBS 진실 미래 영진 블랙 화이트리스트 확인',
#  '언니 죽인 찾아 나선 동생 레몬',
#  '총리 강기정 논란 송구 스럽다 감정 절제 종합',
#  '퇴직 연금 적금 금리 상품 자동 갈아탄다',
#  '예나 빼곤 고만 고만 남자배구 최대 화두 토종 경쟁력',
#  '첼시 우승 이끈 콘테 이제 FA 우승하러 가야',
#  '트럼프 비난 탄핵 조사 증언 군인 국방 장관 보복 없어 진화',
#  '순창 옥천 미술관 외국인 작가 대전 개최',
#  '인제 빙어 축제 태동 원조 겨울 축제',
#  '북한 날씨 고온 현상 건강 관리 유의',
#  '전교조 충북 지부 교육청 학생 안전 책임 행정',
#  '이해찬 기념 행사 평양 실시 감격 평화 공존 도로 종합',
#  '우리카드 나경 외인 없이 나가는 이유 대화',
#  '심부전 치료 부작용 없는 심장 자극 개발',
#  '녹십자 랩셀 줄기세포 치료 정부 과제 선정',
#  '관광객 무역 전쟁 중인 미국 대신 유럽 발길 돌려',
#  '한류 원조 백제 즐기다 문화제 일간 열려',
#  '미륵사지 석탑 수리 공개',
#  '사드 보복 무차별 이후 명동 중국 단체 관광객 사라질수도',
#  '갤럭시 전작 판매량 넘어설까 엇갈린 관측',
#  '한국 GM 수입 협회 에도 가입 쉐보레 수입 판매 늘린다',
#  '베스트셀러 가시노 게이고 연애 행방 인기 종합',
#  '올레 tv 키즈 랜드 출시 모바일 육아 가이드 제공',
#  '한화 생명 빌딩 계단 오르기 이색 마라톤 개최',
#  '승리 즐거움 동시 프로농구 구단 감독 출사표',
#  '린드블럼 김재호 쐐기 두산 한화 위닝 시리즈',
#  '호날두 노쇼 유벤투스 무책임 거만 비판 수용 어려워',
#  '경기 북부 오존 주의보 해제',
#  '알뜰폰 SK 링크 갤럭시 중고 최대 할인',
#  '유승민 민심 분노 임계 치를 넘어섰다 변해야',
#  '금융 꿀팁 보험료 싸지만 함정 있는 해지 환급 보험',
#  '아시안 게임 은색 vs 은색 한국 베트남 관중 뜨거운',
#  'SNS 돋보기 페이스북 창립 SNS 중독 경고 적당히 즐겨야',
#  '디셈버 컴퍼니 보어 바이 투자 일임 서비스 출시',
#  '올해 작품 오은 시인',
#  '후쿠시마 수산물 분쟁 패배한 아베 EU WTO 개혁',
#  '올림픽 성공 평창동계올림픽 하여',
#  '시리아 정부 휴전 선언 반군 지역 공습 중단',
#  'DSR 규제 가동 하니 대출 소득 대비 원리금',
#  '노트 동남아 호주 출시 행사 말레이시아 매진',
#  '오늘 선거구 정안 처리 무산 경계 조정 혈투 합의 지연 종합',
#  '신간 미안 수업 클래식 스크린 흐르다',
#  '폼페이 카슈끄 살해 사건 은폐 않을 조사 계속',
#  '통일부 사회 통합 탈북민 정책 방향 발표',
#  '호주 온두라스 꺾고 번째 국가 월드컵 본선 진출',
#  '대통령 무술년 정국 구상 돌입 개헌 처법 최대 현안',
#  '전국 맑고 포근한 가을 강원 영동 오후',
#  '조배숙 평화 걸음 진전 문재인 정부 가장 잘한',
#  '김정은 생일 전방 대북 확성기 방송 개시',
#  '민통선 걷는 재외동포 학생',
#  '최고 수입 운동선수 올해 호날두 메시 위로 밀려 포브스',
#  '연륙교 공사 어업 피해',
#  '류현진 부부 애리조나 한국 식당 다저스 동료 식사',
#  '안락사 논쟁 붙나 헌재 내주 법적 심리 개시',
#  '대통령 핵실험 준비 상황 포착 내부 대비 중요',
#  '대한항공 우리카드 꺾고 연승 GS 칼텍스 라운드 전승 종합',
#  '사드 본말전도 주장 방중 검토 강력 촉구 종합',
#  '만에 명동 예술 극장 다시 찾은 연극 가족',
#  '프로배구 KB 손해 보험 용병 거포 브람 입국',
#  '윤동주 시집 하늘 바람 판본 경매 출품',
#  '슈퍼 슬로모션 체험',
#  '국내 대규모 개인 데이비드 호크',
#  '브라운 보스턴 밀워키 꺾고 플레이오프 연승',
#  '방통위 신분증 스캐너 문제 없다 보급 종합',
#  '달여 앞둔 남북정상회담 준비 박차',
#  '울림 전북 마을 미디어 네트워크 창립',
#  '두산 중공업 두산 밥캣 전량 처분 키로 재무 개선 종합',
#  '한국 뮤지컬 어워즈 트로피 들고 활짝',
#  'LG 스마트폰 분기 영업 손실 흑자 전환 눈앞 종합',
#  '프로야구 골프 아이돌 라이브 무료 개방',
#  '아웃사이더 처럼 공격 점철 트럼프 출정 연설',
#  '베트남전 찾은 박항서 감독 베트남 강합니다',
#  '대통령 유승민 복당 새누리당 협의 판단 문제',
#  '에도 인터넷 이용 아태 스마트폰 이용',
#  '서울 올림픽 주제가 작사 서울대 교수 별세 종합',
#  '강원 산간 오후 한파 주의보 겨울 번째',
#  '민주 평화 발기인 대회',
#  '나경 보낸 우리카드 가빈 빠진 한국전력 승리',
#  '신간 거대한 전환 대한민국 골든타임',
#  '마당 걸린 오방 조각',
#  '전대 대학생 등록금 반환 요구 경제 대책 마련 해야',
#  '민주 콩고 국경 넘은 에볼라 우간다 감염 사례 확인',
#  '미국 수단 유혈사태 독립 조사 촉구 수단 군부 부정',
#  '머스크 스페이스 올해 번째 로켓 발사 기록',
#  '일본 대만 연승 프리미어 슈퍼 라운드 진출 종합',
#  '정책 기획 위원 박수 받으며 입장 하는 대통령',
#  '정책 조정 회의 참석 하는 홍영표',
#  '메탄올 연료 전지 핵심 부품 개발 드론 장시간 비행',
#  '한컴 오피스 소프트웨어 기반 말랑말랑 플랫폼 오픈',
#  '유례 없는 대강 대치 여야 정치 계산',
#  '두산 자회사 아이피 홀딩스 흡수 합병 결정',
#  '트럼프 우파 언론인 앞세워 벼랑 탈출 나서나',
#  '투스크 브렉 시트 연기 합리 메이 문제 해결 종합',
#  'SKT 상용 구축 현황 공개',
#  '진해 벚꽃로 터널 내년 군항제 반짝반짝 종합',
#  '국내 최대 식품 산업 전시회 개막 개국 참여',
#  '온도 감각 처리 하는 새로운 대뇌 영역 찾았다',
#  '민주 콩고 동부 최대 도시 에볼라 환자 WHO 확산 우려 종합',
#  '브라질 최대 정당 호세프 결별 탄핵 가능성 커져',
#  '만에 매치 팔카오 콜롬비아 역대 다득점 우뚝',
#  '에르도안 북키프로스 천연가스 권리 포기 않을',
#  '대통령 질문 직접 선택 발언권 얻으려 인형 등장',
#  '김관영 프랜차이즈 불공정 조항 계약 원천무효 법안 발의',
#  '뉴욕 경선 트럼프 압승 괴력 힐러리 샌더스 접전 종합',
#  '신규 코픽스 연속 하락',
#  'LG 계승 가폰 IFA 공개',
#  '폭염 이긴 지리산 포도 수확',
#  '대신 증권 현대 글로비스 현대 모비스 합병 수혜 예상',
#  '사우디 외국인 영주권 발급 수수료 천만원',
#  '영국 자연 임신 같은 체외수정 시술 도입',
#  '제주 산간 호우 주의보 장마전선 영향',
#  '과학기술 훈장 웅비 최인 생명연 책임 연구원',
#  '매체 핵실험 아들 이름 강국 지은 부모 소개',
#  '대통령 한미 대북 압박 연대 강화 도발 강력 제재',
#  '스모그 막는 스카프 미래 웨어 러블 기기 될까 호주 구상',
#  '마지막 브리핑 하는 박수현 대변인',
#  'INF 이행 선언 임박 개월 탈퇴 수순',
#  '공항 폭풍 차단 진력 내부 단속 여론 강화',
#  '홍준표 북핵 CVID 합의 하면 회담 파기 해야 종합',
#  '의장 원내대표 소집 필리버스터 신청 한국 불참',
#  '올림픽 한반도기 흔들며 환영',
#  '푸틴 쿠릴 개섬 일본 반환 계획 없어 반환 불가 거듭 확인',
#  '존슨 총리 아일랜드 브렉 시트 정상회담 제안 수용',
#  '유엔 위원회 핵실험 규탄 결의 채택',
#  '민주 콩고 소형 비행기 추락 최소 사망 종합',
#  '김장 안철수 논문 표절 보도 조작 지시 없다',
#  'SK 텔레콤 글로벌 IT 업체 공동 협력 방안 논의',
#  '게시판 SK 텔레콤 갤럭시 개통 고객 제휴 혜택 제공',
#  '여야 미사일 발사 규탄 한반도 평화 논의 찬물',
#  '국방부 터키 시리아 군사작전 지지 안해',
#  '유엔 평화협정 중앙아프리카공화국 난민 귀국 시작',
#  '아베 일본해 국제사회 유일 호칭 변경 필요 없다',
#  '트럼프 효과 멕시코 트럭 타고 국경 이동 이민자 적발',
#  '중미 출신 캐러밴 행렬 멕시코 진입',
#  '충돌 하는 한국 민주당',
#  '의정부 을지대 병원 초대 병원 윤병우 박사',
#  '대통령 아베 한일정상회담 분만 종료',
#  '확진 속출 부산 사하구 모든 학교 이틀 수업 개교 대상',
#  '전기자동차 배터리 전극 소재 개발 충전 단축 기여',
#  '금투 금통위 일부 위원 매파 성향 강화',
#  '독일 이어 프랑스 이란 마한항공 운항 중단 제재 동참',
#  '시리아 인권 단체 하얀 헬멧 설립 터키 숨진 발견',
#  '보수 단체 북한 방송 공동 제작 검토 방통위 국보법 위반',
#  '게시판 착한 텔레콤 SKY 서비스 센터 중고 매입 판매',
#  '카메라 뉴스 만산 홍엽 막바지 절정 이룬 내장산 단풍',
#  '대통령 김일성 만났던 하메네이 면담 압박 외교',
#  '에인절스 라우트 달러 계약 공식 발표',
#  '현금 지급 아냐 추신수 아들 클럽 하우스 봉사자',
#  '대통령 비핵화 협상 중단 시사 보고 받아 북한 물밑 접촉 종합',
#  '대중교통 파업 파리 시내 자전거 사고 급증',
#  '바른 미래 김관영 원내대표 사퇴 원내대표 뽑는다 종합',
#  'EU 집행 위원장 차기 도부 인선 결론 못내 논의 종합',
#  '전화 스콜 아이폰 서도 실시간 발신 정보 확인',
#  '국고 금리 빼고는 하락',
#  '김영란 시대 둬야 십계명',
#  '세계 이식 학회 학술 대회 서울 유치 확정',
#  '유로존 EU 분기 잠정 GDP 성장 분기 보다 하락',
#  '양제츠 정치국 위원 내일 오전 방한 북중 정상회담 결과 설명 종합',
#  '오픈넷 포털 규제 방안 인터넷 표현 자유 위축 우려',
#  'SKT LGU 재난 문자 받는 무료 교체 종합',
#  '탈레반 일시 휴전 동의 평화협정 체결 날짜 조만간 공표',
#  '남산 예술 센터 우연 극장 이후 임차 운영 불가능',
#  '아시안 게임 박항서 베트남 네팔 꺾고 연승',
#  '택배 노동자 과로사 방지 대책 시급',
#  '예술의전당 연속 공공기관 고객 만족도 우수',
#  '네이버 전문 자료 검색 내년 구글 따라잡을',
#  '디우프 인삼공사 GS 칼텍스 제압 건설',
#  'LG 쿠웨이트 핵심 상권 프리미엄 브랜드 오픈',
#  '마틴 우리카드 코치 리그 복귀 한국 좋아요',
#  '김무성 대통령 검찰 수사 조속 받아야',
#  '미국 야구 대표팀 지라디 감독 사임 MLB 맡을',
#  '올해 신협 새마을금고 상호금융 영업 대출 증가',
#  '코스피 보합 마감',
#  '총선 내일 공식 선거운동 시작 열전 돌입',
#  'DLF 손실 라임 환매 중단 사모펀드 잇단 고음',
#  '이란 합의 이행 단계 축소 개시 우라늄 농축 가속',
#  '양자컴퓨터 개발 게임 아이디어 얻는다',
#  '그래픽 소비자 심리 지수 추이',
#  '잊을 만하 수입 배출 가스 조작 FCA 적발',
#  'AI 확산 무섭지만 정유년 새해 희망',
#  '정규 리그 챔프 우승 좌절 징크스 대한항공 깰까',
#  '얼빠진 프로배구 작년 플레이 경기 알아차려',
#  '구내식당 하는 윤석열 검찰총장',
#  '베트남 고아 합창단 운영 하는 박성민',
#  '효성 방통위 원장 분리 공시 제로 통신비 부담 줄이겠다 종합',
#  '맞은 타구 야수 정면 강정호 타수 안타',
#  '북한 선박 국내 입항 금지 근거 만들어',
#  '국민의당 도부 사퇴 대위 체제 위원장 박지원',
#  '해킹 광고 문자 호텔 외식 업체 개인정보 관리 실태 점검',
#  '이태규 정부 대북 인도 지원 이명박 정권 보다 적어',
#  '가사 근로자 법안 업계 전문가 간담',
#  '가맹 본부 점주 묻지마 판촉 넘기기 한다',
#  '인터파크 도서 독자 맞춤 추천 해주는 도서 집사 서비스',
#  '지난해 영업 이익 억원 증가',
#  '코스피 부양책 반등 출발 회복 종합',
#  '망명 영호 베테 외교관 금수 출신 서유럽',
#  '신간 중독 시대',
#  '이주열 시장 변동성 내외 금리 차로 자금 유출 가능성 배제',
#  '조선대 소상 공인 매장 개월 임대료 감면',
#  '초조대장경 유가사지론',
#  '만의 콘텐츠 위해 직장 벗어난 명의 유튜브 창작',
#  '마크 푸틴 파리 단독 회담 주요 분쟁 출구 전략 모색',
#  '에어아시아 아시아 도시 공짜 여행 주인공 공모',
#  '차기 금융투자 협회장 도전 선출 종합',
#  '현대 사료 지난해 영업 이익 억원 감소',
#  '황석영 작가 미국 문학 축제 국문학 알린다',
#  '프로농구 DB 사상 최초 최저 연봉 챔프 우승 도전',
#  '대통령 북핵 갈수록 악화 변국 확실히 알려야',
#  '만화 신간 기분 없는 기분 목소리 들린다면',
#  '한국인 리프 한국 선수 라는 자부심 갖고 뛰겠다',
#  '신간 신우 목사 이스라엘 이야기',
#  '신간 구독 좋아요 경제학',
#  '어느샌가 벌써 있네',
#  '화웨이 ZTE 제재 탄압 중지 해야 발끈',
#  '송민순 회고록 놓고 국기 문란 정치 공세 종합',
#  '놀다 가련 세계 마당 페스티벌 목포 개막',
#  '왕치산 영토 분쟁 인도 외교 장관 만나 협력 강조',
#  '다저스 감독 류현진 직구 제구 번째 타순 공략',
#  '대통령 대한민국 혼란 벗어나 궤도 돌아가길 바라는 마음 속보',
#  '국민의당 리베이트 의혹 재판 선거 홍보 TF 존재 했는지',
#  '위치 정보 규제 풀어 자율 행차 활성화 차위 해커 합의 종합',
#  '금투 CJ 헬로 실적 개선 지속 목표',
#  '차량 폭탄 테러 배후 콜롬비아 최후 반군 인질 석방',
#  '대통령 한국 아이스하키 파이팅',
#  '성인 포털 뉴스 댓글 조작 의심 된다',
#  '서울역 이태원 관광버스 주차장 생긴다',
#  'KBL 군산시 소년 클럽 농구대회 개최 협약',
#  'LG 최첨단 센서 탑재 손짓 화면 조작',
#  '유엔 주재 이스라엘 대사 서안 정착 합병 추진 안해',
#  '발언 하는 장진영',
#  '게시판 미래부 글로벌 상용 소프트웨어 백서 제작',
#  '최준용 쐐기 점포 프로농구 SK 전자랜드 꺾고 연승',
#  '민주 콩고 에볼라 사망자 개월 만에 천명 육박',
#  '중학생 몰던 승용차 도로 돌진 충돌 숨져',
#  '올림픽 평창 만난 대통령 북한 김영남 최고 인민 회의 상임 위원장',
#  '네이멍구 광산 갱도 차량 사고 사망 부상',
#  '작년 임대 사업자 신규 등록 대비',
#  '삼성 이메일 인터넷 브라우저 다운로드 돌파',
#  '경기도 자체 개발 지능 로봇',
#  'KT 울릉도 초등생 VR 콘텐츠 체험 선사',
#  '이재 노동 코로나 휴직 휴업 업주 지원 강화 추진',
#  '애플 무선 충전 패드 에어 파워 내달 출시',
#  '아프간 축구 대표팀 성폭행 파문 확대 조짐',
#  '손흥민 아시안 게임 출전 할까 대표 차출 가능성 미지수',
#  '조원 규모 선박 평형 시장 선점 정부 지원 확대',
#  '전북 최고 대설주의보',
#  'LG PC 마우스 스마트폰 제어 하는 출시',
#  '이집트 엘시 시도 대판 파라오 되나 빛바랜 아랍',
#  '보단 일화 놓고 감치 충돌 재현',
#  '감아도 얼굴 인증 구글 픽셀 보안 논란',
#  '적십자 서울시 생활 치료 센터 코로나 구호 지원',
#  '사과 포도 과일 집중 육성 경북 투입',
#  '사진 대상 임안 불안 불감증 사이 헤매는 한국 담아',
#  '거리 건설 중지 전투 인력 함경북도 피해 복구 투입',
#  '금투 비트코인 가격 오르면 채권 금리 오른다',
#  '주말 여행 충청권 오늘 금메달 리스트 중앙 과학관 올림픽 체험',
#  '리비아 통합 정부 국제 형사재판 소가 군벌 하프 타르 기소 해야',
#  '법원 유착 의혹 코로나 휴정 에도 오늘 재판',
#  '에이 나인 미디어 주식 억원 어치 취득 분율',
#  '귀엽지만 묵직한 무민 이야기 어른용 소설',
#  '까짓 꽃샘추위 이야 전국 축제 상춘 인파',
#  'LG 내달 출시 프리미엄 라인업 확대',
#  '공화 전대 트럼프 후보 수락 연설 풍선 피날레',
#  '명호 의원 고용 산업 위기 지역 고통 경감 법안 발의',
#  '청년 고용 정책 대학생 서포터즈 수고 많았다',
#  '프로농구 SK 정규 리그 최종 KCC 꺾고 위로 직행',
#  'LG 출시 기존 동시 AI 업데이트',
#  '방통위 경기 방송 방송 중단',
#  '브렉 시트 라지 대표 극우 포퓰리즘 그룹 합류',
#  '내달 카카오 게임 개사 주식 의무 보유 풀린다',
#  '이노 비즈 테크 지스 개발 중인 라이',
#  '이란 조원 잭팟 수주 발판 역대 최대 경제성',
#  'KT DS 검증 인프라 갖춘 AI 컨택 센터 플랫폼',
#  '인종차별 규탄 에도 아랑곳 않는 트럼프 이기는 싸움',
#  '수상소감 밝히는 작가',
#  '캐나다 BC 승용차 트럭 차량 무공 전환',
#  'KT 브루클린 서밋 글로벌 협력 논의',
#  '대통령 이인영 원내대표 당선 축하 전화 격려 메시지',
#  '총리 국회 서비스 임시국회 통과 협조 해야 종합',
#  '게시판 KT 바이오 랩스 스마트 산후조리 시스템 구축 MOU',
#  '네이버 스타트업 유럽 진출 돕는다 프로그램 운영',
#  '여자배구 대표팀 VNL 주차 선수 확정',
#  '베스트셀러 김훈 신작 공터 직후 올라',
#  '한국은행 년도 신입 직원 행식',
#  '시라크 대통령 별세 소식 현직 총리 애도',
#  '베트남 리도 카드 쓰는게 안전 카드 발급 허용 논란',
#  '공연 드라마 처럼 다시 보기 추진 연극 샌드백 시도 주목',
#  '목성 주위 위성 발견 목성',
#  '이스라엘 역사 녹은 희비극 마리',
#  '아이카 스트랩 SKT 억원 규모 중계기 납품 계약',
#  '보험사 보험금 지급 비율 분기 하락',
#  '대통령 칠레 대통령 정상회담 비핵화 여정 지지 당부',
#  '신간 동전 오기 전집 현대 정치철학 가지 흐름',
#  'SKT 에릭슨 장비 모듈 시연',
#  '트럼프 발끈 주권국 허락 필요 없어',
#  '리커창 크로아티아 도착 동유럽 일대일 러브콜',
#  '터키 에르도안 휴전 합의 완전 이행 않으면 작전 재개',
#  '사람 같은 기능 가진 인공 시냅스 소자 개발',
#  '홍영표 탄력 근로 확대 노동 현안 국회 처리',
#  '백색 LED 발광 효율 저하 원인 규명',
#  '솔릭 강풍 초속 기록 기상청 들어 보지 수준',
#  '캠코 억원 규모 국유 부동산 공매 대부',
#  '난민 독일 정부 상대로 늑장 심사 한다며 소송',
#  '물방울 바위 구멍 뚫듯 수행 만든 조각 그림',
#  'FBI 용의자 외국 테러 조직 잠재 영감 얻어 진화 종합',
#  '스위스 EU 시장 개방 압박 대응 보호 조치 시행',
#  '조기 출시 효과 톡톡 삼성 스마트폰 영업',
#  '고려대 년도 학기 등록금 반환 운동 TF 발족 기자회견',
#  '유영민 장관 민관 협력 기술 서비스',
#  '방위성 레이더 갈등 협의 발표 항의 사실 달라 주장 종합',
#  'MWC 세계 이통 협회 한국 모바일 활용 연속 세계',
#  '이주 노동자 주거권 보장',
#  '질의 하는 윤한 의원',
#  '황창규 회장 시장 싸우는 방식 달라졌다',
#  '백인 우월 주의 단체 KKK 집회서 폭력 사태 흉기 찔려',
#  '구글플레이 기프트 코드 온라인 판매 개시',
#  '태국 선관위 의도 위헌 소지 비례대표 배분 심판 청구',
#  '톰프슨 골든 스테이 포틀랜드 이틀 패배 설욕',
#  '방통위 방송 평가 제도 개선 공개 토론회 개최',
#  '우간다 대통령 북한 안보 군사 협력 중단',
#  '유엔 인권 보장 인민 생활 향상 최선 주장',
#  '달러 환율 천장 수도',
#  '네이버 웹브라우저 웨일 퀄컴 플랫폼 최적화 된다',
#  '대우버스 울산 공장 폐쇄 반대 기자회견',
#  '레바논 헤즈볼라 국경 지역 이스라엘 드론 격추',
#  'TV 등장 김정은 지지도 사적',
#  'LA 레이 커스 제임스 공백 딛고 새크라멘토 설욕',
#  '북한 미술 획일 다양한 표현 양식 독창 확보',
#  '풍력 발전기 죽는 독수리 실제 많다',
#  '정의당 한노총 노동 개혁 저지 최저임금법 연내 개정 추진',
#  '도쿄 야스쿠니 합사 철회 소송 진술 유족 유수',
#  '황금 연휴 에는 동해 숙박 음식점 할인',
#  '대통령 한미 비핵화 원칙 공조 강화해야',
#  '행복 도시락 평창올림픽 폐회식 준비 인력 도시락 공급',
#  '강철 서신 김영환 확성기 포격 폭풍 견뎌야',
#  '정국 위기 분수령 대통령 정당 수뇌부 연정 논의',
#  '추신수 경기 연속 안타 타율',
#  '이란 외무 제재 NPT 추가 의정서 조기 비준 가능 종합',
#  '보존 처리 마친 국보 반가사유상 공개',
#  '보좌 회의 직원 생중계',
#  '한국 노총 광주 일자리 반대 하는 민주 노총 그릇된 목소리',
#  '이집트 피라미드 위로 떠오르는 태양',
#  '김해 공항 면세점 사업자 롯데 선정',
#  '매서운 바람 추위 호남 제주 내일',
#  'DNA 복구 관여 하는 스캐폴드 단백질 발견',
#  '오페라 슈퍼스타 네트 렙코 목소리 성해졌죠',
#  '옛날 신문 잡지 연구 모던 경성 문화',
#  '세계 괴테 연구자 영애 새로 번역 하는 괴테 전집',
#  '신간 한국 철학 이다 분노 화사',
#  '여행 소식 주한 외국 관광 협회 신규 임원 선출',
#  '유가 상승 교역 조건 지수 개월 만에 최저',
#  '방송 리수용 방중 귀국',
#  '조선일보 TV 조선 주식 부당거래 의혹 수사 착수 고발 조사',
#  '소행성 종말론 없다 나사 지구 충돌 방지 계획 발표',
#  '원자력 연구원 박원석 전자통신 연구원 김명준',
#  '월드컵 한국 경기 관중 천명 최고 시청률',
#  '환영 하는 도미 대표이사',
#  '이해찬 한국 국회법 지켜 정상화 너무도 뻔뻔',
#  '삼화 페인트 공업 주당 현금 배당',
#  '김혜나 작가 이해 되는 사람 들여다보고 싶어요',
#  '제임스 이탈 레이 커스 새크라멘토 패배',
#  '중국 황금 연휴 겨냥 서울시 외국인 관광객 환대 주간',
#  '대구 경북 오늘 무더위 오를',
#  '구조조정 재원 잇단 바꾸기 금융시장 불안 커진다',
#  '제주 수학여행 고교생 식중독 의심 환자 늘어 종합',
#  '최태웅 현대 캐피탈 감독 이승원 오현 코치 마음속 MVP',
#  '콜롬비아 정부 평화협정 국민투표 인준 캠페인 돌입',
#  '인도 야당 총재 집권 하면 모든 빈곤층 기본소득 보장',
#  '한국 콜마 코스 맥스 승승장구 매출 조원 시대',
#  '여야 예산안 내일 처리 패스트 트랙 법안 상정 보류',
#  '연봉 롯데 가을 야구 좌절 책임 고조',
#  '중랑구 동진 학교 설립 협약',
#  'AI 비서 시대 기계 인간 음성 대화',
#  '민주 한국 안위 소위 충돌 소집 날치기 진행',
#  '이지윤 바이올린 명품 연주 금호 아트 한해 만난다',
#  '중동 파견 되는 호위함 다카 나미',
#  '미리 보는 MWC 삼성 갤럭시 독무대 예고 경쟁 없다',
#  '프로배구 꼴찌 한국전력 지탱 하는 서재덕 미소',
#  '삼성 갤럭시 폴드 천원 일부 유통 결제 시작',
#  '동화 기업 분기 연결 영업 억원 감소',
#  '시리아 요청 동맹국 시큰둥 계획 차질 우려',
#  '토성 탐사선 카시니 여정 우주 산화',
#  '실업 급여 지급 지난달 천억원 개월 조원 돌아',
#  '신간 블록 체인 혁명 남자 고독사',
#  '정상 회의 생각 잠긴 대통령',
#  '두산 분기 영업 이익 억원 작년 보다',
#  '네이버 검색어 순위 개인화 이벤트 할인 뜨게 조절 한다',
#  '과학기술 경제 발전 수단 으로만 보지 말라 개헌 토론회',
#  '판매 최고 인기 자격증 드론 조종사',
#  '상사화 고운 식물원',
#  '폴란드 스파이 사건 화웨이 검토 강력 반발 종합',
#  '밀레 세대 배워라 롯데 젊은 직원 영진 멘토링',
#  '노웅래 복수국적 전역 하면 한국 국적 자동 유지 법안 발의',
#  '밤샘 서기 등장 했지만 예전 같지 않은 아이폰 열기 종합',
#  '모다페 홍보 대사 문소리 멀리 있는 예술 아냐',
#  '권창훈 프랑스 리그앙 데뷔 디종 역전패',
#  '운용 후선 업무 지원 하는 자산운용 센터 출범',
#  '금융 연구원 올해 성장 망치 하향 조정',
#  '전북 이동국 경기 자동',
#  '노트 보니 멀티태스킹 최적화 대화면 패블릿 종합',
#  '괴물 공격수 가빈 디우프 우승 부사 될까',
#  'PC 브라우저 최신 업그레이드 하세요',
#  '이인영 황교안 막말 회사 이중 CEO',
#  '정통부 아프리카 학생 대상 RD 교육 추진',
#  '아시안 게임 박항서 응원 하자 베트남 열기 카르',
#  '오성운동 당원 정안 가결 좌파 포퓰리즘 연정 눈앞',
#  '리켐 억원 규모 배정 유상증자 결정',
#  '주류 고량 내리막 수입량 만에 급증',
#  '뇌물 혐의 무죄 김성태 총선 매진 정권 전횡 맞설',
#  '국제 신문 송문석 신임 사장 선임',
#  '대전 교육청 기관 업무 협약 학교 초등 돌봄 운영',
#  '김현 도움 아산 부산 역전승 리그 선두',
#  '코스피 기관 팔자 내려 앉아',
#  '유해 가스 감지 능력 높인 나노 센서 개발',
#  '서울 고교 학년 수업 초교 등교 유지 종합',
#  '특징 개발 대규모 공사 수주 소식 강세',
#  '국립 중앙 박물관 이집트 미라 나볼 세계 화관 개관',
#  '대통령 목선 포착 하고 국민 알린 철저 점검',
#  '전북 미세먼지 기습 종일 뿌연 하늘 곳곳 콜록콜록',
#  'KT 국내 최초 NBIoT 네트워크 상용',
#  '프로배구 개팀 시범 경기 일정 확정 용병 거포 디우프 출격',
#  '농업 공약 확약 홍준표',
#  '국민의당 세월호 인증샷 조직 음해 법적대응',
#  'KIA 임창용 만에 선발 무실점 역투',
#  'EPL 맨유 센터백 바이 발목 수술 개월 아웃',
#  '코로나 위기 넘자 대학생 기부 행렬 줄이어',
#  'NBA 샌안토니오 연속 플레이오프 진출 먹구름',
#  'MLB 워싱턴 셔저 부상 날벼락 WS 선발 로스 교체',
#  '카카오페이지 동영상 영화 서비스 출시',
#  '공백 신속 대체 하는 더타임스 시리아 분할 감독',
#  '베스트셀러 김영하 여행 이유',
#  'KB 손해 보험 의정부 청소년 클럽 배구 대회 개최',
#  '유승민 남경필 이제',
#  '의장 한반도 평화 재일 우의 기회 심기 일전 하자',
#  '신용카드 선택 주목 하는 할인 커피',
#  '여자 프로배구 FA 배유나 도로공사 잔류 결혼',
#  '김정은 생모 생일 앞두고 유선 종양 연구소 띄우기',
#  '주말 여행 강원 호반 도시 스릴 넘치는 레저 묘미 첨벙',
#  '전광인 없어도 한국전력 KOVO 현대 캐피탈 격파 종합',
#  '파주 북어 워드 저작 수상자 중국 리보',
#  '고립 홍콩 공대 위생 악화 정부 시위 평화롭게 나오라',
#  '재고 떨이 노트 공짜 전환 품귀 현상',
#  '하위 KB 손해 보험 우리카드 역전승 시즌 연승',
#  '대회 중앙 통신 평양 경축 분위기 개회 언급 없어',
#  '국회 유남석 헌재 소장 임명 의안 가결',
#  'LG 가폰 KT 가장 싸다 종합',
#  'GS 건설 동탄 레이크 테라스 분양 성한 이벤트',
#  '홀로 서기 유승민 공천 파동 피해자 수혜자',
#  '총기 폭력 비용 연간 조원 GDP 규모',
#  '대통령 국면 전환 위해 내각 바꾸는 어렵다',
#  '굽히지 않는 건립 취지 경과 보고 오정훈 언론노조 위원장',
#  '떨어져서 식사',
#  '트럼프 파월 의장 위협 해임 권한 있어',
#  '카드 적금 금리 마케팅 가세 혜택',
#  '강정호 MLB 시범 경기 타수 안타 안타',
#  '김병준 지지 모임 검다리 포럼 내일 출범',
#  '미군 북부 시리아 천명 철수 준비 일부 이미 이동 종합',
#  '주말 여행 호박 익어가는 계절 시코쿠 여행 묘미',
#  '가상 화폐 대책 입법 갑론 국회 정책 간담',
#  '대부 업체 자회사 활용 저축은행 우회 인수 막는다',
#  '주택 보증 공사 개포 에이치 개포 분양 보증 발급 종합',
#  'SKT 통신 지연 최고 줄인 GX MEC 개발',
#  '마힌드라 회장 쌍용차 천억원 투자',
#  '프랑스 재무 브렉 시트 현재 프랑스 경제 영향 없어',
#  '현대 건설 작년 영업 이익 억원 대비 증가 종합',
#  '북미 정상회담 비서실 김여정 김정은 맹활약 종합',
#  '신태용 침몰 시킨 비슈차 한국 수비 문제 있었다 종합',
#  '에는 MLB 시범 경기 라고 복구 예외 없다',
#  'ICBM 요격 능력 키우는 신형 미사일 위협 대비 실험 종합',
#  '이집트 정부 무슬림형제단 직원 사살 테러 모의 혐의',
#  '고개 숙인 자유 한국 초선 의원',
#  '신태용 감독 아시아 모리뉴 월드컵 성공 물음표',
#  'SKT 로밍 서비스 누적 천만 돌파 출시 개월',
#  '러시아혁명 트로츠키 혁명 번역본',
#  '대전 교육청 모든 학교 학생 탈의실 완비',
#  '라바 여자배구 대표팀 감독 배구 공격 배구',
#  '아시안 게임 해원 여자배구 감독 태국 만나면 해왔다',
#  '원주 중학생 코로나 추가 확진 태권도 장서 감염',
#  '하든 폭발 트리플 더블 맹활약 NBA 휴스턴 연승',
#  '하나카드 해외 여행객 혜택 마이 트립 카드 출시',
#  '농협 허식 부회장 필승 코리아 펀드 가입',
#  '서울 아파트 셋값 상승 전환 이사철 수요 움직 이나',
#  '오바마 대통령 미국 대학농구 미시간주립대 우승 예측',
#  '분자 탄생 과정 원자 움직임 천조분 초단 위로 실시간 관찰 했다',
#  'NC 웨이 한국 대만 연예인 자선 야구 참여',
#  '올림픽 강원 미디어 센터 올림픽 성공 개최 지역 홍보 앞장',
#  '신영석 한국 선수권 경기 대만',
#  '신간 아웃사이더 반란',
#  '리튬 대신 나트륨 체전 국내 구진 개발',
#  '사용 기한 지나 사라진 통신사 마일리지 억원',
#  '번가 MD 품질 보장 선물 세트 출시',
#  '여행 소식 뉴욕 관광명소 입장권 이벤트',
#  '맘껏 뛰놀자 영주 유아 체험',
#  '신간 옥스퍼드 과학사 도시 세계사',
#  '검찰 국민의당 김수민 총선 홍보물 리베이트 압수수색 종합',
#  '네이버 AI 뉴스 편집 조회 증가',
#  '황금 연휴 마을 에버랜드 가장 붐빌',
#  '그래픽 지난해 부자',
#  '영상 운전대 잡자마자 심정지 충돌 사고 운전자 살렸다',
#  '그래픽 현대 기아차 점유 추이',
#  '남자배구 아시아 선수권 강팀 확정 올림픽 예선 전초전 돌입',
#  '올림픽 KT 평창 세계 서비스 준비 끝냈다 선언 종합',
#  '우즈베크 일부 선수 변화 경기 다시 보여야',
#  'LG 미국 출시 완료 시리즈 처음 유럽 시장 노크',
#  '인터 불스 에스 밸류 주식 억원 어치 매각',
#  '나경원 아들 연구 저자 논란 특혜 없어 조국 타기',
#  '한국 투자 증권 해외 주식 모바일 누적 거래 천억 돌파',
#  '베어링 운용 증시 기초 여건 우호 위험 요건 상존',
#  '민주 전대 전쟁 시작 차기 도부 역할 갑론 박도',
#  '시베리아 한반도 서울 인천 만에 한파 경보',
#  '홍종학 이동걸 창업 활성화 손잡는다 협업 프로그램 검토',
#  '현대차 쏘나타 라이즈 택시 판매',
#  '국토부 도시재생 분야 예비 사회 기업 지정',
#  '프리미어 개막전 베네수 에르 제압',
#  '성폭행 의혹 넥센 박동원 조상우 경찰 소환조사',
#  '여야 대표 화기 애애',
#  '그리스 이도 메니 난민캠프 폐쇄 절차 캠프 분산 배치',
#  '이해관계 얽혀 세기 난제 문화재 환수',
#  '목사 올랜도 총격 테러 안전 망언',
#  '신년 회견 중계 대통령 개헌 특위 합의 하면 정부 준비',
#  '우체국 알뜰폰 위탁 판매 확대 난항 우본 노사 이견',
#  '긴장감 대통령',
#  '유비 쿼스 홀딩스 작년 연결 영업 억원 감소',
#  '수석 휴가 복귀 정상 근무 종합',
#  '작년 육아휴직 남성 돌파 사용자 아빠',
#  '한국 당권 주자 전당대회 연기 않으면 후보 등록 거부',
#  'EU 브렉 시트 내년 개월 탄력 연기 합의 종합',
#  '정국 이슈 삼킨 파문 개헌 동력 하루 만에 약화',
#  '모멘트 보다 아름다운 투표',
#  '환경 차관 박천 기상청장 김종석 대통령 차관 인사 종합',
#  '넥센 타격 코치 바꾼 NC 안타 득점 방망이',
#  '제주 밀듯 오던 증가 둔화 원인',
#  'KTB 투자 증권 최대 주주 변경 조회 공시 요구',
#  '인천 서해 강화군 대설주의보 백령도 cm 종합',
#  '경남 취약 노동자 소득 코로나 이전 보다 감소',
#  '노동신문 과학자 동원 연일 능력 선전',
#  '최강 한파 강원 평창 제외 전역 한파 특보 해제 추위 풀려',
#  '현대 카드 카드 신청 분만 발급 서비스',
#  '베를린 최연 악장 출신 블라허 내달 독주 무대',
#  '올해 MWC 황창규 KT 회장 통신 산업 비전 제시',
#  '임금 노동 무기 베트남 로봇 자동화 물결 위기 경고',
#  '캠핑장 차량 남성 숨진 발견',
#  'SKT 중심 전면 조직 개편 세대 교체 인사 종합',
#  '존슨 의회 봉쇄 여왕 브렉 시트 격랑',
#  'SKB 가정 맞아 키즈 콘텐츠 대폭 강화',
#  '재난 현장 뚫고 평창 성화 봉송 하는 휴보',
#  '대통령 프랑스 도착 수교 주년 경제 문화 외교',
#  '유럽 각국 코로나 대응 긴급 언론 지원 프랑스 천억원 예산',
#  '김정은 노동당 위원장 추대 대회 폐막',
#  '방심위 소주 분수 방송 SBS 미우 법정 제재',
#  '유은혜 교육 정책 중점 연구소장 협의 코로나 대응 논의',
#  '유엔 인권 기구 카슈끄 사건 재판 정성 우려',
#  '아시안 게임 박항서 매직 베트남 시리아 꺾고',
#  '자본주의 만든 사치 사치 자본주의 개정판',
#  '젊은 작가 발굴 대산 대학 문학상 수상자 발표',
#  '압력 강도 감지 하는 터치스크린 기술 개발',
#  '삼성 진화 빅스 공개 달라질까',
#  '정확성 높인 유전자 가위 생쥐 유전자 교정 성공 종합',
#  'MBC 충북 특집 다큐 공부 씨앗 방영',
#  '프로배구 현대 캐피탈 센터 영석 오는 결혼',
#  '강원 한파 기승 대관령 영하 평년 기온 회복',
#  '루프 펀딩 금융 협회 탈퇴 단기 연체 넘겨',
#  '문제 백악관 트럼프 아니라 내면 트럼프',
#  'EU 이란 유조선 나포 긴장 심화 깊이 우려',
#  '경기 교육청 수원 부천 유치원 휴업 명령 고양 권고',
#  '여전한 거수기 사외이사 작년 대기업 이사회 찬성',
#  'SKB 영상 보안 오픈 플랫폼 클라우드 API 포털 출시',
#  '에이수스 휴대 모니터 스크린 MB AC 출시',
#  '문재인 대통령 기무사 계엄령 문건 독립 사단 구성 특별 지시',
#  '라이베리아 반군 사령관 스위스 전쟁 범죄 혐의 기소',
#  '부산 교육 무직 갑질 괴롭힘 피해 경험',
#  '정보 문화 청소년 SW 대회 열려',
#  '지방선거 승패 가를 변수',
#  '폭증 신용 대출 가상 화폐 시장 갔나',
#  '신종 코로나 국내 확산 성균관대 올해 입학식 취소',
#  '노트 이색 컬러 마케팅 SKT KT 전용 색상 출시',
#  '샤넬 헤밍웨이 애용 파리 리츠 호텔 보수 화재',
#  '노원 일자리 박람회',
#  '서울 사흘 최저 기온 기록 경신 가장 추웠던',
#  '국경절 행사 공연 중인 터키 우정 합창단',
#  '사이 테크 플러스 얼굴 사진 분석 희귀 유전 질환 진단 AI 개발',
#  '다산 네트웍 람보르기니 IT 합작 법인 설립',
#  '내달 출시 아이폰 년틀 유지 디자인 가격 다양',
#  'KT 스카이 ITU 어워즈 글로벌 산업 수상',
#  '신임 금융감독원장 정무 저격수 김기식 의원 내정 종합',
#  '즐라탄 머리 밟은 밍스 경기 출전 정지 징계',
#  '여행 휴식 문체부 니스 관광 선정',
#  '신간 한국 개신교 타자 인식 행복한 비움',
#  '지주회사 해외 사례 공부 하는 공정위',
#  '화천 산천어 축제 북적',
#  '지리산 유람선 경남 해넘이 맞이 명소',
#  '최고 부호 음악인 웨버 젊은 에서는 에드 시런',
#  '툰베리 밝은 미래 고대 하는 소녀 트럼프 조롱 응수',
#  '특징 블록딜 불확실 걷힌 삼성 만원 회복 종합',
#  '난민 입항 막던 극우 부총리 미성년 상륙 동의',
#  '강원 공립 유치원 교사 직장 괴롭힘 겪었다',
#  '한국은행 기준금리 동결',
#  '신간 밥상머리 디톡스 혼밥 생존',
#  '연일 미세먼지 어린이 놀이터 청소',
#  '얼어붙은 세종시 부동산 시장',
#  '현대 캐피탈 AI 알려주는 시세 확인 해보세요',
#  '바이러스 인체 세포 침투 구조 규명',
#  '한국인 디지털 기기 미디어',
#  '슬로모션 카메라폰 소니 엑스페리아 XZ 프리미엄 공개',
#  '홍콩 시위 실탄 맞아 중태 시진핑 초상 태우며 애도 시위 종합',
#  '현대 연말 천억 선박 수주 이란',
#  '생활임금 중점 법안 점화 부심 법안',
#  '알뜰폰 시장 후끈 만원 무제한 요금 가입자 쇄도 종합',
#  '황금색 변기 앉아 트윗 하는 트럼프 로봇 등장',
#  '여자배구 대표팀 세터 안혜진 부상 조기 귀국',
#  '금감원 보험 대리점 전국 순회 교육',
#  'LG 분기 영업 이익 작년 동기 대비',
#  '년대 그린란드 얼음 손실 년대',
#  '연패 빠질 뻔한 LG 구한 최동환 도움 되도록 노력',
#  '상의 중소기업 농어 협력 재단 산업 혁신 운동 업무 협약',
#  '연정 내분 살비 부총리 문제 없다 연정 유지 강조',
#  '대통령 국민 단합 믿어 DNA 대륙 기상',
#  '눈사람 추워요',
#  '타수 안타 탬파베이 미네소타 완패',
#  '반미 감정 조성하 한국 전쟁 연일 집중 조명',
#  '특징 LG 구광모 테마주 상한 LG 그룹 주는 등락 엇갈려',
#  '신간 위대한 호수',
#  '최신 영화 미끼 악성 파일',
#  '김태형 두산 감독 김재환 내일 쉽지는 않을',
#  '민주 보고서 논란 지속 국적 정국 전략 집중 포화',
#  '스완지 역전 손흥민 상위 평점',
#  'LG 유플러스 LTE 라우터 와이파이 슬림 출시',
#  '말레이 언론 무산 위기 일대일 철도 사업 추진 합의',
#  '음악가 출발 백남준 음악세계 연구 조속 이뤄져야',
#  '사개특위 대신 정개 특위 위원장 맡기로 위원장 홍영표',
#  '수능 응원전 없는 수능',
#  '한중일 언론 교류 세미나',
#  '특징 유위 니아 코스닥 상장 첫날 종합',
#  '해양 고세균 감염 시키는 바이러스 발견 기후변화 예측 도움',
#  'AI 월드컵 생생한 현장 중계',
#  '태풍 산산 발생 에도 우리나라 피해 간다',
#  '맨유 맨시티 완승 루카쿠 래시 퍼드 연속',
#  '프로농구 KCC 추승균 감독 자진사퇴',
#  '중국 에코 한국 시장 조용히 진출 내년 스마트폰 들여와',
#  '매체 개성 공단 입주 기업 벼랑 떠밀어 주장',
#  '감사 보고서 지연 제출 속출 외감법 보수 감사',
#  '유은혜 수도권 학교 단계 미리 준비 조희연 원격 전환 해야 종합',
#  '알바 구인 정보 서비스 라인 바이트 일본 인기',
#  'LG 공식 사과 사인 훔치기 논란 불미 스러운 종합',
#  '국고 금리 일제 상승 년물',
#  '대통령 여야 원내대표 소상 공인 규제 혁신 민생 법안 처리 속보',
#  '대신 증권 JB 금융 광주 은행 여지 인수 수익 개선',
#  '추문 만화가 박재동 피해자 사과 책임지겠다',
#  '지안 고구려 유적 조사 보고서 통구 발간',
#  'NBA 마지막 미네소타 덴버 대결 이기 PO',
#  '봄꽃 활짝 세종 시청',
#  'TV 조선 연애 목요일 이동',
#  '신간 그것 대해 아주 오랫동안 생각',
#  '대통령 국회 연설 북한 대화 제로',
#  '브라질 상파울루 빛난 주얼리 공예 앙상블 명품 한류 눈길',
#  '하남 미사 강변 도시 상업 용지 분양',
#  'LGU 데이터 속도 용량 완전 무제한 금제 국내 출시',
#  '예멘 반군 사우디 남부 공항 공격 민간인 부상',
#  '아시아 블록 체인 테크 컨퍼런스',
#  '대통령 사이 두고 개헌 민감',
#  '홍콩 갑부 리카싱 호주 에너지 회사 천억원 인수 제안',
#  '광주 전남 교육청 수능 접수 마감 작년 보다 감소',
#  '반포 평화 심포지엄 축사 하는 나경원 원내대표',
#  'CCTV 포착 속초 리프트 추락 분간 멈췄다가 순식간 추락 종합',
#  '한국 문화재 재단 장구 명인 이성진 추모 공연',
#  '강정호 경쟁자 모란 시즌 홈런 피츠버그 연승',
#  '국무회의 상임 했으면 국회 정부 일정 존중 요청',
#  '일본 스포츠 청장 관도 고교야구 투구 제한 환영',
#  '부산 특성 마이스터고 직업 교육 온라인 박람회',
#  '케냐 열린 개천절 행사 한복 패션쇼',
#  '강정호 경기 연속 침묵 경쟁자 모란 결승 점포',
#  '조원 경기 부양책 실효 의문 달러 전망',
#  '세운 메디 분기 영업 억원 증가',
#  '주당 분기 배당 결정',
#  '한산한 대학 캠퍼스',
#  '해피 버스 데이 사라 예술의전당 파티',
#  '이슬람 학회 학자 세계 이슬람',
#  '대전 충남 동장군 기승 청양 영하 종합',
#  '이란 대통령 카타르 군주 통화 양국 관계 생산',
#  '대통령 올림픽 유치 고맙다 MB 성공 좋겠다',
#  'MBN 방송사고 보도국 징계',
#  '충북 늦더위 계속 가을비',
#  '롯데 제과 사옥 인공 지능 안내 로봇 배치',
#  '연결 세상',
#  '김종인 리먼 브라더스 사태 처럼 경제 충격 지속 되지 않을',
#  '국문학 앤솔로지 영문 은세계',
#  'WSL 우승 지소연 점수 만점',
#  '송환 촉발 홍콩 여자친구 살인 대만 가서 자수 하겠다',
#  'SK 링크 최고 천원 국제 전화 마음껏 쓰세요',
#  '무디스 롯데 쇼핑 신용등급 Baa 강등',
#  '동정 위성 신한은행 대전 충청 지역 기업 고객 만나',
#  '석촌동 고분 유적 살펴보는 학예사',
#  'SKT 글로벌 ICT 명소 주목 받는 티움',
#  '프로야구 마쓰자카 사인 해주다 어깨 부상',
#  '이스라엘 시리아 이란 표적 공습 임박 드론 공격 저지 종합',
#  '낙스 주가 급등 관련 중요 정보 없다',
#  '대통령 지지율 유지 역대 최저 경신 종합',
#  '세계 탄소 출국 인도 내달 파리 기후 협정 비준',
#  '몰타 대통령 벨라 외무 장관 지명 내달 취임 예정',
#  '장마전선 북상 오후 제주 남부 지방 확대',
#  '금융 위원장 인터넷 은행 내년 인가 금융 혁신 계기',
#  '코스닥 사흘 오르며 개월 만에 회복',
#  '울산 옹기 축제 놀러 오세요',
#  '미드 체르노빌 촬영 리투아니아 원전 사고 공포 휩싸여',
#  '윈팩 주가 급등 관련 조회 공시 요구',
#  '어린이 참변 당한 고덕동 주택 현장 감식',
#  '현대 노조 임협 난항 부분파업 회사 집회 자제 해야',
#  '한국 금융 시스템 최대 위험 보호무역 가계부채',
#  '사우디 예멘 반군 폭격 반군 드론 공격',
#  '트럼프 테러 직후 현장 달려가 왔다 재차 주장',
#  '코스닥 펀드 출시 열흘 만에 조원 자금 몰이',
#  '카카오 게임 평균 이용 자수 돌파',
#  '남자배구 굳어진 구도 선두 싸움 혼전',
#  '노시 노래 치열한 시대 인식 선집 백두 머리 두고',
#  '공공기관 대기업 여성 관리자 절반 기준 미달',
#  '스노우맨 우체국 알뜰폰 판매 TV 인터넷 결합 상품 출시',
#  '캐나다 홍콩 시위 격화 여행 주의보 격상',
#  '청주 후기 소각 건립 반대',
#  '산재 사망 노동자 추모 하는 참석자',
#  '성균관대 선후배 장병철 신진식 감독 대결 기대되',
#  '부산 만에 남자 농구 매치 월드컵 지역 예선',
#  '총리 독립유공자 후손 정부 차원 노력 계속',
#  '이라크 티그리스강 침몰 여명 사망 종합',
#  '신간 헤겔 아더 인즈',
#  '기다리는 이재영 PO 플레이어 알리 파튜',
#  '의원 북유럽 러시 한국 미래 롤모델 찾기',
#  '잉글랜드 축구 기성용 최근 경기 연속 결장',
#  '임준 수협 중앙회 당선인 부정선거 의혹 해경 압수수색 종합',
#  '의암호 실종 경찰 정서 발견 장비',
#  '매체 미군기지 무수단 미사일 공격 영상 공개',
#  '소자 브라질 호주 친선 전서 대승',
#  '현대 캐피탈 꼴찌 OK 저축은행 완파 하고 선두 굳건',
#  '주말 여행 강원 고맙다 추위 날씨 포근해 미룬 겨울 축제 속속 개장',
#  '탈북 한국 영국인 왕실 국가 공로 훈장 받아',
#  '얻는 시진핑 미니 성사 해외 순방 통해 입지 다져 종합',
#  '던진 창조 제안 석탄 섬유 수출 금지 유보',
#  '터키 병사 무장 단체 교전 전사 부상',
#  'KT 비즈메카 이지 이용 고객 돌파',
#  '남북 정상 오후 판문점 선언 서명',
#  '패럴림픽 기상 이상무 평년 보다 기온 오를',
#  '줄기세포 분화 시기 조절 물질 찾았다',
#  'MBC 명예퇴직 세종 MBC 구축 권역별 광역 추진',
#  '게시판 KT 베어 파크 에어 코리아 플랫폼 구축',
#  '항의 구호 외치는 한국',
#  'NH 투자 외국인 한국 채권 매수 전환 자금 이탈 진정',
#  '프로배구 라운드 종료 우리카드 도약 GS 칼텍스 강세 지속',
#  '울산 시청 모인 건설 노조 조합원',
#  '개통 초반 발화 사고 제로 배터리 고비 넘긴',
#  '이란 이란 매파 볼턴 경질 에도 대화',
#  '빅텍 방위사업청 억원 규모 전자전 장비 공급',
#  '오승환 나란히 결장 동반 패배',
#  '북러 교역 지난해 대비 감소 정세 불안 영향',
#  '프로야구 선수 협회 경기 심판 질의 금지 유감',
#  '민주 탈당 조경태 새누리 최고 참석 입당 공식 속보',
#  'SNS 돋보기 노쇼 근절 적정 조처 vs 너무 약하다',
#  '캔버스 피운 조각 전광영 삼청동 개인',
#  '주택 금융 공사 주택 증권 수익률 산출 방식 통일',
#  '특징 앤지 억원 공급 계약 강세',
#  'IS 격퇴 앞장섰지만 이라크 시리아 버림 받은 쿠르드',
#  '대선 주자 트럼프 연방 항소 법원 판사 친누나 딴판',
#  '투병 경험 음악회 서울시 브람스 교향곡',
#  '국내 기술 광석 찾았다 억원 상당',
#  'JP 모건 운용 증시 조정 경고 분기',
#  '안타 KRX 코스닥 종목 직접 수혜 제한',
#  '그래픽 한진 한진 이미 담보 제공',
#  '연평도 코앞 김정은 잇단 전방 위협 수위 높여',
#  '이란 합의 제한 농도 넘겨 우라늄 농축 합의 최대 위기 종합',
#  '게시판 한국 신문 윤리 위원회 정선 신미 위원 위촉',
#  '남자배구 미국 에도 무릎 세계 예선 올림픽 직행 실패',
#  '매체 피츠버그 강정호 결별',
#  '감사원 수리과학 연구소 연구 보다 워크숍 강연',
#  '갤럭시 덱스 지원 하는 최적화 오피스 출시',
#  '이해인 수녀 시집 사계절 기도 개정 증보',
#  '박원순 지방자치 확대 하는 분권 개헌 논의 진행 돼야',
#  '유진 재단 보건 방북 일정 연기 통보',
#  '등교 개학 계절 어느덧 하복',
#  '올림픽 결승선 통과 북한',
#  '게시판 KT 신규 LTE 에그 슬림에그 출시',
#  '여야 히말라야 사고 원정 애도 수습 최선 다해 주길',
#  '앙숙 관계 실세 부총리 사법 개혁 놓고 정면 충돌',
#  '이란 호르무즈 봉쇄 감히 예고 자신감 부각',
#  '서금 신복위 코레일 손잡고 서민 금융 열차 운행',
#  '시청자 명중 스마트폰 방송 본다',
#  '중국 미국 제품 최고 관세',
#  '안우진 이닝 무실점 PS 평균자책점',
#  '네덜란드 댄스 시어터 내한 공연 간담',
#  '이란 CIA 고정간첩 체포 사형 선고',
#  '아시안 게임 한국 축구 강전 우즈베크 유린',
#  '코트디부아르 외딴 시골 환자 돌보는 격진 시스템',
#  '호날두 FIFA 올해 선수 연속 수상 메시',
#  'KT 차이나모바일 로밍 블록 체인 협력',
#  '독립운동가 출신 경찰관 생존자 확인 광복군 활동 김영진',
#  '화웨이 미국 제재 계속 되면 올해 하량 천만 감소',
#  '은빛 세계 변신 북한 인수',
#  '코스피 코로나 우려 급락 대로 후퇴 종합',
#  '김성식 재벌 비정규직 모인 라운드테이블 마련 해야 종합',
#  'BMW 코리아 배터리 용량 늘린 Ah 출시',
#  '제주도 산지 대설주의보 해제 한라산 진달래',
#  'LG 화학 분기 영업 억원 분기 만에 최대 종합',
#  '수술 앞둔 환자 납치 국경없는의사회 예멘 아덴 활동 유보',
#  '아시안 게임 의조 골골 한국 박항서 매직',
#  '홍준표 너무 나갔다 한국 남북 합의 대응 기조 갈등',
#  '남북정상회담 김여정 인사 하는 대통령',
#  '터키 시리아 정부 공격 받는 이들립 반군 무기 지원 종합',
#  '나경원 대통령 쇄국 주의 다시 구한말 아베 만나야',
#  '서는 동해안 강원 지역 해수욕장 개장',
#  '충주 소식 환경 관리원 공개 채용',
#  '증시 상품 미래에셋 대우 해외 주식 ELS 포함 판매',
#  '서울 성동구 성수동 수제 작업장 환경 개선 지원',
#  '참가자 발언 듣는 전광훈 목사',
#  '민주 추상 같은 국민 명령 책임감 평화 민생 과제 박차 종합',
#  '구글 마인드 저장 회로 적용 기술 신경망 발표',
#  'KBO 야구 주년 맞아 한국 야구 유물 전시',
#  '공정 경제 전략 회의 입장 하는 대통령',
#  '방통위 결합 상품 해지 방해 통신사 업자 단속',
#  '거래소 지엔 변동 조회 공시 요구',
#  '내년 베네치아 비엔날레 한국 예술 감독 공모',
#  '중국 유화 메시지 위험 선호 재개 달러 환율 하락',
#  '신간 죽음 넘어 한국 지역 문학 연구',
#  '노회찬 무상급식 의무 홍준표 방지법 발의',
#  '대우건설 분기 영업 억원 증가 종합',
#  '박지원 청와대 행진곡 현행 대로 합창 결정 통보 해와',
#  '한국 GDP 대비 연구개발 투자 세계',
#  'SKT 스마트그리드 KT 정보보안 통신사 통신',
#  'EU 차기 도부 논의 진전 있으나 아직 합의',
#  '억울한 노동자 지원 서울시 노동 권리 보호 증원',
#  '김홍 검사 사건 검찰 수사 심의 내달 소집 종합',
#  '공천 탈락 박대동 의원 재심 청구 받아들이면 무소속 출마',
#  'KT 휴대전화 액정 보험 무료 제공 잠금 화면 출시',
#  '포근한 봄날 기지개 미세먼지 에도 마스크 쓰고 들로',
#  '한강 김언수 유명 작가 예테보리 도서전 문학 행사',
#  '추가 부동산대책 앞둔 시장 긴장감 할까',
#  '기자 해병대 목사 이란 억류 수년 만에 자유 찾은 미국 인들',
#  '현대 로템 학대 피해 아동 심리치료 천만원 지원',
#  '남자배구 아시아 선수권 파키스탄 승리',
#  '류현진 투수 무덤 이닝 무실점 호투 에도 빈손',
#  '연대 감사 결과 학생 분노',
#  '주말 여행 제주 인류 무형 문화유산 해녀 문화 만나다 숨비 소리',
#  '도용 신고 폐쇄 김종인 페북 계정 나흘 만에 복구 종합',
#  '다산초당 명품 좋은 이름 없나요 강진군 공모',
#  '문턱 넘은 황창규 KT 미래 먹거리 쏟는다',
#  '선양 롯데 월드 중순 공사 재개 예정',
#  '롯데 백화점 올해 매장 테마 사회 공헌',
#  '문체부 야영장 미등록 최대 천만원 벌금 처분',
#  '작년 이동통신 번호 이동 만에 최저 평균 만건',
#  '주민 자치 센터 강사 코로나 생계 지원 지급 촉구',
#  '롯데 홈쇼핑 국립국어원 홈쇼핑 언어 사용 지침 발간',
#  '전문 대통령 광복절 축사 책임 있는 강국 뚜벅뚜벅',
#  '미래부 기초과학 연구원 성과 평가 착수 구단 대상',
#  '아시안 게임 돌아온 문장 조현우 무실점 금메달',
#  'KCGI 한진 영진 책임져야 한진 앞두고 지지 호소',
#  '셀트리온 제약 작년 영업 억원 감소 종합',
#  '평창올림픽 외국인 안내 AI 통역 로봇 나온다',
#  'LG 스켈레톤 황제 성빈 선수 격려 억원',
#  '현대 글로비스 중국 콜드 체인 시장 진출',
#  '모바일 게임 라미 퍼즈벤처 글로벌 다운로드 달성',
#  '경기도 취업 창업 준비 청년 공간 올해 확충',
#  '고를까 고민 되네 속속 드러나는 하반기 프리미엄',
#  '학기 앞두고 학생 잇단 감염 비상 교육부 교외 감염 추정',
#  '보험사 대출 잔액 조원 주택 담보 대출 증가 전환',
#  '여자농구 우리은행 삼성 생명 꺾고 연승 선두 질주',
#  '증시 상품 홍콩 지수 선물 버스 ETF',
#  '남자배구 번째 한일전 패배 아시아 선수권 위로 마감',
#  '두산 밥캣 스캇 성철 단독 대표이사 변경',
#  'SBS 노조 태영 갈등 검찰 공정위 윤석민 회장 고발',
#  'LG 친환경 공조 솔루션 유럽 시장 뚫는다',
#  'FIFA 월드컵 개최 비리 폭로 부랴부랴 보고서 공개',
#  '코스피 개인 기관 매수 이틀 반등 회복 종합',
#  '날씨 한파 주춤 아침 기온 모레 다시 추워져',
#  '정진석 원내대표 출마 일방 당청 관계 지속 불가능',
#  'EU 협상 난항 에도 브렉 시트 승인 투표 예정 대로',
#  '고개 숙인 강정호 타수 삼진 교체 타율',
#  '남북 정상 수산물 만찬 다녀가면 유명한',
#  '교보 증권 코오롱 글로벌 분기 깜짝 호실 목표 주가',
#  '충청권 인권 노동 단체 이주 노동자 안전 보장 제정',
#  '대통령 빠르게 경제 행보 다시 고삐 죈다',
#  '청명 일요일 전국 맑음 교차 감기 조심하세요',
#  '김종인 야권 통합 카드 국면 전환 목적 포석 승부',
#  '플로리다 클럽 총격 사망 최소 부상 테러 수사 속보',
#  '중형 태풍 탈림 북상 제주 비바람 중부 쾌청',
#  '힐러리 샌더스 CNN 토론 자유무역 견해 놓고 격론',
#  '퀄컴 커넥티드',
#  '현대 캐피탈 대체 외국인 선수 찾았다 오켈 사실 확정',
#  '여성 경청 박영숙 두고 왔을 리가 없다',
#  '에도 서울 거리 술집 천지 였네',
#  '순진 합참의장 미국 방문 미사일 대응 방안 논의',
#  '그룹 들어 투자 줄였다',
#  '저커버그 카메라 증강현실 플랫폼',
#  '박근혜 정부 지지율 파노라마 지지율 고수',
#  'MLB 슈퍼스타 라우트 통산 WAR 지터 추월',
#  '멕시코 네덜란드 대승 프리미어 예선 전승',
#  '유전자 편집 원자폭탄 수도 사회 윤리 논의 해야',
#  '시애틀 개막 경기 연속 홈런 ML 최초',
#  '미국 조준 먼로 주의 역사 역주행 비난',
#  '폭력 극단 주의 부르는 SNS 혐오 표현 세계 문제 종합',
#  '배구 여제 김연경 월드컵 통해 대표팀 희망 봤다',
#  '필리핀 중국 여대생 무례 발칵 뒤집혀',
#  '이벤트 지켜보자 달러 환율 상승 출발',
#  '등교 하며 소독 발열 검사 필수',
#  '그래픽 글로벌 브랜드',
#  '아름다운 마무리 BTS 메시지 러브 셀프',
#  '민주 의원 간담 회서 사드 배치 의견 조율 시도',
#  '여자배구 김세영 국가대표 은퇴 선언 김해 재활 전념',
#  '황주홍 특활비 대안 만원 수급 거절 국회 필요 최소 제안',
#  '대통령 긴장 북핵 대응 올인 미르 법도 내놓을까 종합',
#  '금값 사흘 연속 최고 행진 가까이 상승',
#  '이스라엘 홀로코스트 미술품 베를린 전시 메르켈 참석',
#  '팔레스타인 의료 봉사자 이스라엘군 피살',
#  '대신 타자 한화 김태균 전혀 서운하다',
#  '드론 띄워 바닷가 실태 조사',
#  '비대 결제 증가 에도 주요 현금 발행 잔액 증가',
#  '사립 교사 채용 대가 거래 재단 관계자 브로커 구속',
#  '주간 화제 뉴스 장성 공관 갑질 파문 관심 계속',
#  'LGU 만원 태블릿 패드 FHD LTE 단독 출시',
#  ...]

# %%
df_test = pd.DataFrame(X_test, columns=['title'])
df_test
# Out:
#                                  title
# 0            한일진공 美 생명과학업체 지분 1.99% 취득
# 1     불법 보조금에 공짜 마케팅까지…이통3사 갤S8 진흙탕 싸움
# 2        평화당 오늘 서대문형무소 역사관서 창당 1주년 기념식
# 3        국민연금 운용수익률 곤두박질…10월말 현재 0.57%
# 4         카톡 에어컨 켜…카카오 AI 삼성 생활가전에도 탑재
# ...                                ...
# 9126  러시아 축구팬 우리 아들 즐라탄 마스코트 시켜주면 뇌물줄께
# 9127    NBA 웨스트브룩 통산 100호 트리플더블…역대 4번째
# 9128    벤처캐피털시장 창투·신기술금융으로 양분…억지통합 말아야
# 9129      장강명 원작 연극 그믐… 다음달 남산예술센터서 재연
# 9130         간디는 인종차별주의자 가나 대학 동상 철거키로
#
# [9131 rows x 1 columns]

# %%
res_test = preprocessing(df_test, stopword)

# %%
## main
X_train, X_test = vectorizor(res, res_test)
models = [
    {'name': 'linear_model.SGD', 'obj': linear_model.SGDClassifier()},    82.68
    {'name': 'neural_network.MLP', 'obj': MLPClassifier(verbose=True, early_stopping=True)}, 
    {'name': 'neural_network.MLP', 'obj': MLPClassifier(verbose=True, early_stopping=True,hidden_layer_sizes=[10], solver='adam',n_iter_no_change=5)}, 
    {'name': 'neural_network.MLP', 'obj': MLPClassifier(verbose=True, early_stopping=True,hidden_layer_sizes=[16], solver='adam')}, 
    {'name': 'neural_network.MLP', 'obj': MLPClassifier(verbose=True, early_stopping=True,hidden_layer_sizes=[64], solver='adam')}, 
    {'name': 'neural_network.MLP', 'obj': MLPClassifier(verbose=True, early_stopping=True,hidden_layer_sizes=[128], solver='adam')},
    {'name': 'neural_network.MLP', 'obj': MLPClassifier(verbose=True, early_stopping=True,hidden_layer_sizes=[256], solver='adam')},
    {'name': 'neural_network.MLP', 'obj': MLPClassifier(verbose=True, early_stopping=True,hidden_layer_sizes=[512], solver='adam')},
    {'name': 'neural_network.MLP', 'obj': MLPClassifier(verbose=True, early_stopping=True,hidden_layer_sizes=[100,100], solver='adam')},
    {'name': 'neural_network.MLP', 'obj': MLPClassifier(verbose=True, early_stopping=True,hidden_layer_sizes=[128,128], solver='adam')},
    {'name': 'neural_network.MLP', 'obj': MLPClassifier(verbose=True, early_stopping=True,hidden_layer_sizes=[512,512], solver='adam')},
    {'name': 'svm.LinearSVC', 'obj': svm.LinearSVC()},   0.8358339721826744
    {'name': 'svm.SVC(linear)', 'obj': svm.SVC(kernel='linear')},   0.8351768700032856
    {'name': 'svm.SVC(poly,2)', 'obj': svm.SVC(kernel='poly', degree=2)},   0.8155733216515169
    {'name': 'svm.SVC(poly,3)', 'obj': svm.SVC(kernel='poly')}, 
    {'name': 'svm.SVC(poly,4)', 'obj': svm.SVC(kernel='poly', degree=4)},
    {'name': 'svm.SVC(rbf)', 'obj': svm.SVC(kernel='rbf')},  0.8247727521629613
    {'name': 'svm.SVC(rbf,$\gamma$=1)', 'obj': svm.SVC(kernel='rbf', gamma=1)}, #82.4
    {'name': 'svm.SVC(rbf,$\gamma$=4)', 'obj': svm.SVC(kernel='rbf', gamma=4)},
    {'name': 'svm.SVC(rbf,$\gamma$=16)', 'obj': svm.SVC(kernel='rbf', gamma=16)},
    {'name': 'svm.SVC(rbf,$\gamma$=64)', 'obj': svm.SVC(kernel='rbf', gamma=64)},
    {'name': 'svm.SVC(sigmoid)', 'obj': svm.SVC(kernel='sigmoid')},
    {'name': 'tree.ExtraTree', 'obj': tree.ExtraTreeClassifier()},
    {'name': 'ensemble.RandomForest(10)', 'obj': ensemble.RandomForestClassifier(n_estimators=10)},
    {'name': 'ensemble.RandomForest(100)', 'obj': ensemble.RandomForestClassifier()},
    {'name': 'ensemble.ExtraTrees(10)', 'obj': ensemble.ExtraTreesClassifier(n_estimators=10)},
    {'name': 'ensemble.ExtraTrees(100)', 'obj': ensemble.ExtraTreesClassifier(n_estimators=100)},
    {'name': 'ensemble.AdaBoost(DTree)', 'obj': ensemble.AdaBoostClassifier(tree.DecisionTreeClassifier())},
]

for model in models:
    # Train a model and evaluate it
    print(model['name'])
    model_c = train(X_train, y_train, model['obj'])
    print(test(model_c, X_test, y_test))
    print('='*100)

# %%
X_train, X_test,vector = vectorizor(res, res_test)

# %%
result = train(X_train, y_train,svm.LinearSVC())

# %%
print(test(result, X_test, y_test))
# Out:
# 0.8358339721826744

# %%
test = pd.read_csv('./data/test_data.csv')
test_data = preprocessing(test, stopword)
res_test = vector.transform(test_data)

# %%
res_test.shape
# Out:
# (9131, 201505)

# %%
def predict(model, x_test):
    pred = model.predict(x_test)
    return pred

# %%
pred = predict(result, res_test)
pred.shape
# Out:
# (9131,)

# %%
pred
# Out:
# array([0, 3, 2, ..., 4, 2, 6])

# %%
test
# Out:
#       index                            title
# 0     45654       유튜브 내달  일까지 크리에이터 지원 공간 운영
# 1     45655          어버이날 맑다가 흐려져 남부지방 옅은 황사
# 2     45656      내년부터 국가RD 평가 때 논문건수는 반영 않는다
# 3     45657  김명자 신임 과총 회장 원로와 젊은 과학자 지혜 모을 것
# 4     45658   회색인간 작가 김동식 양심고백 등 새 소설집  권 출간
# ...     ...                              ...
# 9126  54780     인천 오후  시  분 대설주의보 눈    cm 쌓여
# 9127  54781    노래방에서 지인 성추행 외교부 사무관 불구속 입건종합
# 9128  54782       년 전 부마항쟁 부산 시위 사진  점 최초 공개
# 9129  54783    게시판 아리랑TV 아프리카개발은행 총회 개회식 생중계
# 9130  54784  유영민 과기장관 강소특구는 지역 혁신의 중심 지원책 강구
#
# [9131 rows x 2 columns]

# %%
test.title = pred

# %%
test
# Out:
#       index  title
# 0     45654      0
# 1     45655      3
# 2     45656      2
# 3     45657      0
# 4     45658      3
# ...     ...    ...
# 9126  54780      3
# 9127  54781      2
# 9128  54782      4
# 9129  54783      2
# 9130  54784      6
#
# [9131 rows x 2 columns]

# %%
test.to_csv('./sample_linear_svc.csv')

# %%
s = '''
아
휴
아이구
아이쿠
아이고
어
나
우리
저희
따라
의해
을
를
에
의
가
으로
로
에게
뿐이다
의거하여
근거하여
입각하여
기준으로
예하면
예를 들면
예를 들자면
저
소인
소생
저희
지말고
하지마
하지마라
다른
물론
또한
그리고
비길수 없다
해서는 안된다
뿐만 아니라
만이 아니다
만은 아니다
막론하고
관계없이
그치지 않다
그러나
그런데
하지만
든간에
논하지 않다
따지지 않다
설사
비록
더라도
아니면
만 못하다
하는 편이 낫다
불문하고
향하여
향해서
향하다
쪽으로
틈타
이용하여
타다
오르다
제외하고
이 외에
이 밖에
하여야
비로소
한다면 몰라도
외에도
이곳
여기
부터
기점으로
따라서
할 생각이다
하려고하다
이리하여
그리하여
그렇게 함으로써
하지만
일때
할때
앞에서
중에서
보는데서
으로써
로써
까지
해야한다
일것이다
반드시
할줄알다
할수있다
할수있어
임에 틀림없다
한다면
등
등등
제
겨우
단지
다만
할뿐
딩동
댕그
대해서
대하여
대하면
훨씬
얼마나
얼마만큼
얼마큼
남짓
여
얼마간
약간
다소
좀
조금
다수
몇
얼마
지만
하물며
또한
그러나
그렇지만
하지만
이외에도
대해 말하자면
뿐이다
다음에
반대로
반대로 말하자면
이와 반대로
바꾸어서 말하면
바꾸어서 한다면
만약
그렇지않으면
까악
툭
딱
삐걱거리다
보드득
비걱거리다
꽈당
응당
해야한다
에 가서
각
각각
여러분
각종
각자
제각기
하도록하다
와
과
그러므로
그래서
고로
한 까닭에
하기 때문에
거니와
이지만
대하여
관하여
관한
과연
실로
아니나다를가
생각한대로
진짜로
한적이있다
하곤하였다
하
하하
허허
아하
거바
와
오
왜
어째서
무엇때문에
어찌
하겠는가
무슨
어디
어느곳
더군다나
하물며
더욱이는
어느때
언제
야
이봐
어이
여보시오
흐흐
흥
휴
헉헉
헐떡헐떡
영차
여차
어기여차
끙끙
아야
앗
아야
콸콸
졸졸
좍좍
뚝뚝
주룩주룩
솨
우르르
그래도
또
그리고
바꾸어말하면
바꾸어말하자면
혹은
혹시
답다
및
그에 따르는
때가 되어
즉
지든지
설령
가령
하더라도
할지라도
일지라도
지든지
몇
거의
하마터면
인젠
이젠
된바에야
된이상
만큼
어찌됏든
그위에
게다가
점에서 보아
비추어 보아
고려하면
하게될것이다
일것이다
비교적
좀
보다더
비하면
시키다
하게하다
할만하다
의해서
연이서
이어서
잇따라
뒤따라
뒤이어
결국
의지하여
기대여
통하여
자마자
더욱더
불구하고
얼마든지
마음대로
주저하지 않고
곧
즉시
바로
당장
하자마자
밖에 안된다
하면된다
그래
그렇지
요컨대
다시 말하자면
바꿔 말하면
즉
구체적으로
말하자면
시작하여
시초에
이상
허
헉
허걱
바와같이
해도좋다
해도된다
게다가
더구나
하물며
와르르
팍
퍽
펄렁
동안
이래
하고있었다
이었다
에서
로부터
까지
예하면
했어요
해요
함께
같이
더불어
마저
마저도
양자
모두
습니다
가까스로
하려고하다
즈음하여
다른
다른 방면으로
해봐요
습니까
했어요
말할것도 없고
무릎쓰고
개의치않고
하는것만 못하다
하는것이 낫다
매
매번
들
모
어느것
어느
로써
갖고말하자면
어디
어느쪽
어느것
어느해
어느 년도
라 해도
언젠가
어떤것
어느것
저기
저쪽
저것
그때
그럼
그러면
요만한걸
그래
그때
저것만큼
그저
이르기까지
할 줄 안다
할 힘이 있다
너
너희
당신
어찌
설마
차라리
할지언정
할지라도
할망정
할지언정
구토하다
게우다
토하다
메쓰겁다
옆사람
퉤
쳇
의거하여
근거하여
의해
따라
힘입어
그
다음
버금
두번째로
기타
첫번째로
나머지는
그중에서
견지에서
형식으로 쓰여
입장에서
위해서
단지
의해되다
하도록시키다
뿐만아니라
반대로
전후
전자
앞의것
잠시
잠깐
하면서
그렇지만
다음에
그러한즉
그런즉
남들
아무거나
어찌하든지
같다
비슷하다
예컨대
이럴정도로
어떻게
만약
만일
위에서 서술한바와같이
인 듯하다
하지 않는다면
만약에
무엇
무슨
어느
어떤
아래윗
조차
한데
그럼에도 불구하고
여전히
심지어
까지도
조차도
하지 않도록
않기 위하여
때
시각
무렵
시간
동안
어때
어떠한
하여금
네
예
우선
누구
누가 알겠는가
아무도
줄은모른다
줄은 몰랏다
하는 김에
겸사겸사
하는바
그런 까닭에
한 이유는
그러니
그러니까
때문에
그
너희
그들
너희들
타인
것
것들
너
위하여
공동으로
동시에
하기 위하여
어찌하여
무엇때문에
붕붕
윙윙
나
우리
엉엉
휘익
윙윙
오호
아하
어쨋든
만 못하다
하기보다는
차라리
하는 편이 낫다
흐흐
놀라다
상대적으로 말하자면
마치
아니라면
쉿
그렇지 않으면
그렇지 않다면
안 그러면
아니었다면
하든지
아니면
이라면
좋아
알았어
하는것도
그만이다
어쩔수 없다
하나
일
일반적으로
일단
한켠으로는
오자마자
이렇게되면
이와같다면
전부
한마디
한항목
근거로
하기에
아울러
하지 않도록
않기 위해서
이르기까지
이 되다
로 인하여
까닭으로
이유만으로
이로 인하여
그래서
이 때문에
그러므로
그런 까닭에
알 수 있다
결론을 낼 수 있다
으로 인하여
있다
어떤것
관계가 있다
관련이 있다
연관되다
어떤것들
에 대해
이리하여
그리하여
여부
하기보다는
하느니
하면 할수록
운운
이러이러하다
하구나
하도다
다시말하면
다음으로
에 있다
에 달려 있다
우리
우리들
오히려
하기는한데
어떻게
어떻해
어찌됏어
어때
어째서
본대로
자
이
이쪽
여기
이것
이번
이렇게말하자면
이런
이러한
이와 같은
요만큼
요만한 것
얼마 안 되는 것
이만큼
이 정도의
이렇게 많은 것
이와 같다
이때
이렇구나
것과 같이
끼익
삐걱
따위
와 같은 사람들
부류의 사람들
왜냐하면
중의하나
오직
오로지
에 한하다
하기만 하면
도착하다
까지 미치다
도달하다
정도에 이르다
할 지경이다
결과에 이르다
관해서는
여러분
하고 있다
한 후
혼자
자기
자기집
자신
우에 종합한것과같이
총적으로 보면
총적으로 말하면
총적으로
대로 하다
으로서
참
그만이다
할 따름이다
쿵
탕탕
쾅쾅
둥둥
봐
봐라
아이야
아니
와아
응
아이
참나
년
월
일
령
영
일
이
삼
사
오
육
륙
칠
팔
구
이천육
이천칠
이천팔
이천구
하나
둘
셋
넷
다섯
여섯
일곱
여덟
아홉
령
영
년
만
안
뭐
으면
을
의
가
이
은
들
는
좀
잘
걍
과
도
년전
하다
'''
stopword = s.split('\n')

# %%
stopword = stopword[1:-1]

# %%
len(stopword)
# Out:
# 696
